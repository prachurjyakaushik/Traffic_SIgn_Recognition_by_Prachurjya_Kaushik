# %%
#Importing Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
Root = "A:\Traffic_Sign_Recognition"
os.chdir(Root)
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7a7dc7ba7bf1> in <module>
#       9 Root = "A:\Traffic_Sign_Recognition"
#      10 os.chdir(Root)
# ---> 11 from sklearn.model_selection import train_test_split
#      12 from tensorflow.keras.utils import to_categorical
#      13 from keras.models import Sequential, load_model
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
#Importing Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
Root = "A:\Traffic_Sign_Recognition"
os.chdir(Root)
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7a7dc7ba7bf1> in <module>
#       9 Root = "A:\Traffic_Sign_Recognition"
#      10 os.chdir(Root)
# ---> 11 from sklearn.model_selection import train_test_split
#      12 from tensorflow.keras.utils import to_categorical
#      13 from keras.models import Sequential, load_model
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
#Importing Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
Root = "A:\Traffic_Sign_Recognition"
os.chdir(Root)
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

# %%
#Storing data and labels in lists
data = []
labels = []
classes = 43
cur_path = os.getcwd()

# %%
#Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)
    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")

# %%
#Converting lists into numpy arrays
data = np.array(data)
labels = np.array(labels)
print(data.shape, labels.shape)
# Out:
# (39209, 30, 30, 3) (39209,)

# %%
#splitting data with the help of sklearn function train_test_split() into training and testing data.
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (31367, 30, 30, 3) (7842, 30, 30, 3) (31367,) (7842,)

# %%
#Converting the labels into one hot encoding
y_train = to_categorical(y_train, 43)
y_test = to_categorical(y_test, 43)

# %%
#Building CNN Model
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-961cf83519fe> in <module>
#       1 #Training of the model
#       2 epochs = 15
# ----> 3 history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))
#       4 model.save("my_model.h5")
#
# ~\anaconda3\envs\Traffic_SIgn_Reccognition\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\envs\Traffic_SIgn_Reccognition\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1029     # Legacy graph support is contained in `training_v1.Model`.
#    1030     version_utils.disallow_legacy_graph('Model', 'fit')
# -> 1031     self._assert_compile_was_called()
#    1032     self._check_call_args('fit')
#    1033     _disallow_inside_tf_function('fit')
#
# ~\anaconda3\envs\Traffic_SIgn_Reccognition\lib\site-packages\tensorflow\python\keras\engine\training.py in _assert_compile_was_called(self)
#    2567     # (i.e. whether the model is built and its inputs/outputs are set).
#    2568     if not self._is_compiled:
# -> 2569       raise RuntimeError('You must compile your model before '
#    2570                          'training/testing. '
#    2571                          'Use `model.compile(optimizer, loss)`.')
#
# RuntimeError: You must compile your model before training/testing. Use `model.compile(optimizer, loss)`.

# %%
#Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Training of the model
epochs = 15
history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))
model.save("my_model.h5")
# Out:
# Epoch 1/15
# 981/981 [==============================] - 56s 57ms/step - loss: 1.9937 - accuracy: 0.5027 - val_loss: 0.5799 - val_accuracy: 0.8676
# Epoch 2/15
# 981/981 [==============================] - 57s 58ms/step - loss: 0.7713 - accuracy: 0.7768 - val_loss: 0.2232 - val_accuracy: 0.9371
# Epoch 3/15
# 981/981 [==============================] - 57s 59ms/step - loss: 0.5605 - accuracy: 0.8365 - val_loss: 0.1689 - val_accuracy: 0.9504
# Epoch 4/15
# 981/981 [==============================] - 58s 59ms/step - loss: 0.4301 - accuracy: 0.8730 - val_loss: 0.1676 - val_accuracy: 0.9500
# Epoch 5/15
# 981/981 [==============================] - 59s 60ms/step - loss: 0.3914 - accuracy: 0.8836 - val_loss: 0.1111 - val_accuracy: 0.9684
# Epoch 6/15
# 981/981 [==============================] - 59s 60ms/step - loss: 0.3593 - accuracy: 0.8946 - val_loss: 0.1028 - val_accuracy: 0.9679
# Epoch 7/15
# 981/981 [==============================] - 59s 61ms/step - loss: 0.3283 - accuracy: 0.9045 - val_loss: 0.0936 - val_accuracy: 0.9731
# Epoch 8/15
# 981/981 [==============================] - 55s 57ms/step - loss: 0.3299 - accuracy: 0.9035 - val_loss: 0.0868 - val_accuracy: 0.9730
# Epoch 9/15
# 981/981 [==============================] - 56s 57ms/step - loss: 0.3000 - accuracy: 0.9117 - val_loss: 0.0908 - val_accuracy: 0.9699
# Epoch 10/15
# 981/981 [==============================] - 56s 57ms/step - loss: 0.2801 - accuracy: 0.9182 - val_loss: 0.0935 - val_accuracy: 0.9741
# Epoch 11/15
# 981/981 [==============================] - 56s 57ms/step - loss: 0.2753 - accuracy: 0.9192 - val_loss: 0.1341 - val_accuracy: 0.9552
# Epoch 12/15
# 981/981 [==============================] - 56s 57ms/step - loss: 0.2992 - accuracy: 0.9100 - val_loss: 0.0786 - val_accuracy: 0.9777
# Epoch 13/15
# 981/981 [==============================] - 56s 57ms/step - loss: 0.2881 - accuracy: 0.9186 - val_loss: 0.0709 - val_accuracy: 0.9776
# Epoch 14/15
# 981/981 [==============================] - 57s 58ms/step - loss: 0.2530 - accuracy: 0.9257 - val_loss: 0.0661 - val_accuracy: 0.9797
# Epoch 15/15
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2724 - accuracy: 0.9234 - val_loss: 0.0874 - val_accuracy: 0.9759

# %%
#plotting graph for accuracy 
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

#plotting graph for loss
plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
#Testing on test data
from sklearn.metrics import accuracy_score

y_test = pd.read_csv('Test.csv')

labels = y_test["ClassId"].values
imgs = y_test["Path"].values

data=[]

for img in imgs:
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))

X_test=np.array(data)

pred = np.argmax(model.predict(X_test), axis=-1)

# %%
#Checking accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(labels, pred))
# Out:
# 0.9345209817893904

# %%
# Classes of trafic signs
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
#making predictions
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
def test_on_img(img):
    data=[]
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))
    X_test=np.array(data)
    pred = np.argmax(model.predict(X_test), axis=-1)
    return image,pred

# %%
#sample image 00034.png
plot,prediction = test_on_img(r'D:\Traffic_Sign_Recognition\Test\00034.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-3714a7089f41> in <module>
#       1 #sample image 00034.png
# ----> 2 plot,prediction = test_on_img(r'D:\Traffic_Sign_Recognition\Test\00034.png')
#       3 s = [str(i) for i in prediction]
#       4 a = int("".join(s))
#       5 print("Predicted traffic sign is: ", classes[a])
#
# <ipython-input-19-5f7f07fc0e78> in test_on_img(img)
#       5 def test_on_img(img):
#       6     data=[]
# ----> 7     image = Image.open(img)
#       8     image = image.resize((30,30))
#       9     data.append(np.array(image))
#
# ~\anaconda3\envs\Traffic_SIgn_Reccognition\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2966
#    2967     if filename:
# -> 2968         fp = builtins.open(filename, "rb")
#    2969         exclusive_fp = True
#    2970
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Traffic_Sign_Recognition\\Test\\00034.png'

# %%
#sample image 00034.png
plot,prediction = test_on_img(r'A:\Traffic_Sign_Recognition\Test\00034.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# Predicted traffic sign is:  Speed limit (50km/h)

# %%
#sample image 00093.png
plot,prediction = test_on_img(r'A:\Traffic_Sign_Recognition\Test\00093.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# Predicted traffic sign is:  Stop

# %%
#sample image 00480.png
plot,prediction = test_on_img(r'A:\Traffic_Sign_Recognition\Test\00480.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# Predicted traffic sign is:  Turn right ahead

# %%
#sample image 00597.png
plot,prediction = test_on_img(r'A:\Traffic_Sign_Recognition\Test\00597.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# Predicted traffic sign is:  Bicycles crossing

# %%
#sample image 00868.png
plot,prediction = test_on_img(r'A:\Traffic_Sign_Recognition\Test\00868.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# Predicted traffic sign is:  Road work
